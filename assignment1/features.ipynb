# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# 'cs231n' folder containing the '.py', 'classifiers' and 'datasets'
# folders.
# e.g. 'cs231n/assignments/assignment1/cs231n/'
FOLDERNAME = 'cs231n/assignments/assignment1/cs231n/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %cd drive/My\ Drive
# %cp -r $FOLDERNAME ../../
# %cd ../../
# %cd cs231n/datasets/
# !bash get_datasets.sh
# %cd ../../
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content
# /content/cs231n/datasets
# --2021-01-11 14:29:56--  http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  97.9MB/s    in 1.7s
#
# 2021-01-11 14:29:58 (97.9 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1
# /content

# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

learning_rates = [1e-9, 1e-7]
regularization_strengths = [5e4, 5e6]


re_run = 300
max_iteration = 300

for i in range(re_run):
  random_learning_rate = learning_rates[0] + np.random.rand() \
    * (learning_rates[1] - learning_rates[0])
  random_regularization_strengths = regularization_strengths[0] \
    + np.random.rand() * (regularization_strengths[1]
                          - regularization_strengths[0])

  #Train
  svm = LinearSVM()
  loss_hist = svm.train(
    X_train_feats,
    y_train,
    learning_rate=random_learning_rate,
    reg=random_regularization_strengths,
    num_iters=max_iteration,
    verbose=False,
    )
  #Accuracy
  y_train_pred = svm.predict(X_train_feats)
  accuracy_train = np.mean(y_train == y_train_pred)

  y_val_pred = svm.predict(X_val_feats)
  accuracy_val = np.mean(y_val == y_val_pred)

  results[random_learning_rate, random_regularization_strengths] = \
    [accuracy_train, accuracy_val]

  if accuracy_val > best_val:
    best_val = accuracy_val
    best_svm = svm

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1.221980e-09 reg 8.045398e+05 train accuracy: 0.100184 val accuracy: 0.107000
# lr 1.583606e-09 reg 4.769303e+06 train accuracy: 0.115796 val accuracy: 0.105000
# lr 1.850701e-09 reg 4.071331e+06 train accuracy: 0.091755 val accuracy: 0.096000
# lr 1.868360e-09 reg 3.871464e+06 train accuracy: 0.123245 val accuracy: 0.119000
# lr 2.340972e-09 reg 7.891651e+05 train accuracy: 0.090592 val accuracy: 0.097000
# lr 2.376042e-09 reg 4.333587e+06 train accuracy: 0.104367 val accuracy: 0.124000
# lr 2.606143e-09 reg 3.500534e+06 train accuracy: 0.076592 val accuracy: 0.061000
# lr 2.794256e-09 reg 4.335450e+06 train accuracy: 0.109837 val accuracy: 0.090000
# lr 3.008624e-09 reg 2.212358e+06 train accuracy: 0.095449 val accuracy: 0.085000
# lr 4.404723e-09 reg 2.559756e+06 train accuracy: 0.093143 val accuracy: 0.104000
# lr 4.719513e-09 reg 1.390477e+06 train accuracy: 0.085837 val accuracy: 0.093000
# lr 5.106450e-09 reg 2.559570e+06 train accuracy: 0.099265 val accuracy: 0.096000
# lr 5.374933e-09 reg 6.856520e+05 train accuracy: 0.117265 val accuracy: 0.115000
# lr 6.660215e-09 reg 3.349903e+06 train accuracy: 0.149592 val accuracy: 0.146000
# lr 6.760312e-09 reg 4.409728e+06 train accuracy: 0.286429 val accuracy: 0.318000
# lr 6.853957e-09 reg 4.028171e+06 train accuracy: 0.206939 val accuracy: 0.226000
# lr 7.280480e-09 reg 2.026642e+06 train accuracy: 0.100612 val accuracy: 0.113000
# lr 7.486674e-09 reg 1.604386e+06 train accuracy: 0.101735 val accuracy: 0.087000
# lr 8.424918e-09 reg 2.737236e+06 train accuracy: 0.122102 val accuracy: 0.135000
# lr 8.456762e-09 reg 4.060430e+06 train accuracy: 0.395286 val accuracy: 0.385000
# lr 8.857473e-09 reg 3.197855e+06 train accuracy: 0.281082 val accuracy: 0.290000
# lr 9.211798e-09 reg 3.454606e+06 train accuracy: 0.365796 val accuracy: 0.381000
# lr 9.517397e-09 reg 3.333885e+06 train accuracy: 0.370673 val accuracy: 0.372000
# lr 9.653826e-09 reg 2.207555e+06 train accuracy: 0.130408 val accuracy: 0.152000
# lr 1.000229e-08 reg 2.356796e+06 train accuracy: 0.148980 val accuracy: 0.164000
# lr 1.018591e-08 reg 1.111378e+06 train accuracy: 0.088163 val accuracy: 0.096000
# lr 1.022745e-08 reg 2.185992e+06 train accuracy: 0.142878 val accuracy: 0.132000
# lr 1.057905e-08 reg 4.687706e+06 train accuracy: 0.410204 val accuracy: 0.408000
# lr 1.075362e-08 reg 3.875220e+06 train accuracy: 0.411306 val accuracy: 0.423000
# lr 1.103044e-08 reg 1.335031e+06 train accuracy: 0.143408 val accuracy: 0.140000
# lr 1.108772e-08 reg 1.034360e+06 train accuracy: 0.094122 val accuracy: 0.095000
# lr 1.326813e-08 reg 4.872907e+05 train accuracy: 0.104367 val accuracy: 0.104000
# lr 1.371143e-08 reg 1.368145e+06 train accuracy: 0.133653 val accuracy: 0.122000
# lr 1.386104e-08 reg 3.744528e+06 train accuracy: 0.404224 val accuracy: 0.403000
# lr 1.413272e-08 reg 5.334797e+04 train accuracy: 0.107551 val accuracy: 0.082000
# lr 1.415857e-08 reg 3.826896e+06 train accuracy: 0.405796 val accuracy: 0.411000
# lr 1.427599e-08 reg 3.074026e+06 train accuracy: 0.404429 val accuracy: 0.398000
# lr 1.484870e-08 reg 3.523438e+05 train accuracy: 0.108204 val accuracy: 0.116000
# lr 1.657570e-08 reg 2.188870e+05 train accuracy: 0.097531 val accuracy: 0.088000
# lr 1.663679e-08 reg 3.337610e+06 train accuracy: 0.408776 val accuracy: 0.395000
# lr 1.684420e-08 reg 4.056563e+06 train accuracy: 0.412204 val accuracy: 0.393000
# lr 1.686422e-08 reg 1.110624e+06 train accuracy: 0.104163 val accuracy: 0.091000
# lr 1.715734e-08 reg 7.981096e+05 train accuracy: 0.121041 val accuracy: 0.143000
# lr 1.796097e-08 reg 3.724836e+06 train accuracy: 0.397980 val accuracy: 0.379000
# lr 1.819473e-08 reg 2.770953e+06 train accuracy: 0.409000 val accuracy: 0.396000
# lr 1.824290e-08 reg 2.657888e+06 train accuracy: 0.413531 val accuracy: 0.416000
# lr 1.837294e-08 reg 2.438842e+06 train accuracy: 0.405592 val accuracy: 0.402000
# lr 1.840827e-08 reg 3.211050e+06 train accuracy: 0.411224 val accuracy: 0.414000
# lr 1.882276e-08 reg 4.876206e+06 train accuracy: 0.396837 val accuracy: 0.403000
# lr 1.938695e-08 reg 2.536678e+05 train accuracy: 0.111735 val accuracy: 0.097000
# lr 1.976213e-08 reg 5.132085e+05 train accuracy: 0.096898 val accuracy: 0.085000
# lr 1.984163e-08 reg 3.527176e+06 train accuracy: 0.410633 val accuracy: 0.409000
# lr 2.068536e-08 reg 6.628585e+05 train accuracy: 0.117306 val accuracy: 0.109000
# lr 2.070525e-08 reg 2.675531e+06 train accuracy: 0.409694 val accuracy: 0.416000
# lr 2.168148e-08 reg 3.497475e+06 train accuracy: 0.407959 val accuracy: 0.409000
# lr 2.200851e-08 reg 4.652198e+06 train accuracy: 0.406694 val accuracy: 0.409000
# lr 2.239735e-08 reg 4.624274e+05 train accuracy: 0.118878 val accuracy: 0.110000
# lr 2.262447e-08 reg 1.891149e+06 train accuracy: 0.409163 val accuracy: 0.411000
# lr 2.295178e-08 reg 3.274769e+05 train accuracy: 0.103918 val accuracy: 0.115000
# lr 2.320192e-08 reg 2.261404e+06 train accuracy: 0.405612 val accuracy: 0.392000
# lr 2.384380e-08 reg 4.666573e+06 train accuracy: 0.406041 val accuracy: 0.389000
# lr 2.463663e-08 reg 7.141001e+05 train accuracy: 0.134000 val accuracy: 0.125000
# lr 2.558501e-08 reg 1.069817e+06 train accuracy: 0.355673 val accuracy: 0.342000
# lr 2.625969e-08 reg 2.333525e+06 train accuracy: 0.405959 val accuracy: 0.398000
# lr 2.646317e-08 reg 1.154650e+06 train accuracy: 0.397041 val accuracy: 0.407000
# lr 2.650022e-08 reg 2.203248e+06 train accuracy: 0.402306 val accuracy: 0.390000
# lr 2.667732e-08 reg 2.704813e+06 train accuracy: 0.401408 val accuracy: 0.397000
# lr 2.689343e-08 reg 2.242632e+05 train accuracy: 0.098776 val accuracy: 0.083000
# lr 2.854389e-08 reg 3.311117e+06 train accuracy: 0.402469 val accuracy: 0.406000
# lr 2.915495e-08 reg 8.436802e+05 train accuracy: 0.279673 val accuracy: 0.260000
# lr 2.944491e-08 reg 4.566796e+06 train accuracy: 0.404204 val accuracy: 0.416000
# lr 2.977567e-08 reg 3.002426e+06 train accuracy: 0.403020 val accuracy: 0.402000
# lr 2.982548e-08 reg 4.017275e+06 train accuracy: 0.407673 val accuracy: 0.413000
# lr 3.049282e-08 reg 2.633827e+06 train accuracy: 0.409776 val accuracy: 0.402000
# lr 3.060147e-08 reg 4.953496e+06 train accuracy: 0.397714 val accuracy: 0.397000
# lr 3.066504e-08 reg 4.032597e+06 train accuracy: 0.407816 val accuracy: 0.403000
# lr 3.077961e-08 reg 2.800471e+06 train accuracy: 0.402163 val accuracy: 0.392000
# lr 3.096371e-08 reg 1.887907e+06 train accuracy: 0.405327 val accuracy: 0.413000
# lr 3.112944e-08 reg 8.240610e+05 train accuracy: 0.327143 val accuracy: 0.300000
# lr 3.138851e-08 reg 3.678286e+06 train accuracy: 0.397204 val accuracy: 0.386000
# lr 3.152679e-08 reg 4.409193e+05 train accuracy: 0.118673 val accuracy: 0.118000
# lr 3.156400e-08 reg 3.279976e+06 train accuracy: 0.412980 val accuracy: 0.419000
# lr 3.168839e-08 reg 3.162556e+06 train accuracy: 0.399224 val accuracy: 0.390000
# lr 3.179821e-08 reg 2.448302e+06 train accuracy: 0.403265 val accuracy: 0.392000
# lr 3.201527e-08 reg 1.645976e+05 train accuracy: 0.098184 val accuracy: 0.101000
# lr 3.207279e-08 reg 8.112710e+04 train accuracy: 0.109918 val accuracy: 0.106000
# lr 3.292495e-08 reg 1.254035e+06 train accuracy: 0.412551 val accuracy: 0.411000
# lr 3.295168e-08 reg 2.490086e+06 train accuracy: 0.406429 val accuracy: 0.402000
# lr 3.334725e-08 reg 5.120430e+05 train accuracy: 0.143429 val accuracy: 0.146000
# lr 3.356336e-08 reg 2.641770e+06 train accuracy: 0.407551 val accuracy: 0.392000
# lr 3.359763e-08 reg 4.530110e+06 train accuracy: 0.401612 val accuracy: 0.402000
# lr 3.361486e-08 reg 3.145844e+06 train accuracy: 0.402347 val accuracy: 0.396000
# lr 3.390765e-08 reg 1.179494e+06 train accuracy: 0.410571 val accuracy: 0.408000
# lr 3.418115e-08 reg 2.344910e+06 train accuracy: 0.398959 val accuracy: 0.398000
# lr 3.437056e-08 reg 4.656897e+06 train accuracy: 0.400735 val accuracy: 0.398000
# lr 3.457806e-08 reg 2.541552e+06 train accuracy: 0.411224 val accuracy: 0.404000
# lr 3.459894e-08 reg 5.108068e+05 train accuracy: 0.148184 val accuracy: 0.170000
# lr 3.464812e-08 reg 1.744422e+06 train accuracy: 0.414306 val accuracy: 0.419000
# lr 3.511195e-08 reg 3.827479e+06 train accuracy: 0.395041 val accuracy: 0.403000
# lr 3.517803e-08 reg 2.793946e+06 train accuracy: 0.414163 val accuracy: 0.411000
# lr 3.571951e-08 reg 4.108279e+06 train accuracy: 0.399224 val accuracy: 0.408000
# lr 3.618715e-08 reg 3.446153e+06 train accuracy: 0.394163 val accuracy: 0.390000
# lr 3.640045e-08 reg 4.914311e+06 train accuracy: 0.394449 val accuracy: 0.390000
# lr 3.641932e-08 reg 3.798160e+06 train accuracy: 0.403306 val accuracy: 0.399000
# lr 3.800113e-08 reg 2.643335e+06 train accuracy: 0.406592 val accuracy: 0.400000
# lr 3.931137e-08 reg 2.945841e+06 train accuracy: 0.407694 val accuracy: 0.400000
# lr 3.936040e-08 reg 2.148944e+06 train accuracy: 0.411204 val accuracy: 0.410000
# lr 3.948397e-08 reg 1.474297e+06 train accuracy: 0.411592 val accuracy: 0.407000
# lr 4.007386e-08 reg 1.434268e+06 train accuracy: 0.405918 val accuracy: 0.406000
# lr 4.052143e-08 reg 1.102487e+06 train accuracy: 0.412367 val accuracy: 0.413000
# lr 4.092769e-08 reg 3.162865e+06 train accuracy: 0.413429 val accuracy: 0.406000
# lr 4.107326e-08 reg 1.451722e+06 train accuracy: 0.410224 val accuracy: 0.403000
# lr 4.115619e-08 reg 3.389655e+06 train accuracy: 0.406082 val accuracy: 0.411000
# lr 4.119915e-08 reg 8.757591e+04 train accuracy: 0.092592 val accuracy: 0.107000
# lr 4.120378e-08 reg 3.769108e+06 train accuracy: 0.407694 val accuracy: 0.394000
# lr 4.162639e-08 reg 2.941074e+06 train accuracy: 0.399755 val accuracy: 0.397000
# lr 4.172757e-08 reg 1.674865e+06 train accuracy: 0.416041 val accuracy: 0.412000
# lr 4.196288e-08 reg 3.065861e+06 train accuracy: 0.406673 val accuracy: 0.390000
# lr 4.217411e-08 reg 2.921912e+06 train accuracy: 0.411020 val accuracy: 0.416000
# lr 4.217591e-08 reg 4.908556e+05 train accuracy: 0.221980 val accuracy: 0.248000
# lr 4.252118e-08 reg 7.924887e+05 train accuracy: 0.417633 val accuracy: 0.423000
# lr 4.342337e-08 reg 3.050307e+06 train accuracy: 0.411082 val accuracy: 0.416000
# lr 4.377665e-08 reg 4.391579e+06 train accuracy: 0.400122 val accuracy: 0.384000
# lr 4.417496e-08 reg 4.317940e+06 train accuracy: 0.390653 val accuracy: 0.380000
# lr 4.435795e-08 reg 1.014735e+06 train accuracy: 0.410449 val accuracy: 0.427000
# lr 4.447607e-08 reg 2.317768e+05 train accuracy: 0.100388 val accuracy: 0.085000
# lr 4.489829e-08 reg 1.292641e+06 train accuracy: 0.404449 val accuracy: 0.404000
# lr 4.494942e-08 reg 3.092318e+05 train accuracy: 0.115408 val accuracy: 0.094000
# lr 4.541490e-08 reg 4.900594e+06 train accuracy: 0.405490 val accuracy: 0.396000
# lr 4.545876e-08 reg 3.565702e+05 train accuracy: 0.150082 val accuracy: 0.153000
# lr 4.556498e-08 reg 2.407607e+06 train accuracy: 0.406122 val accuracy: 0.406000
# lr 4.595251e-08 reg 3.236109e+06 train accuracy: 0.404755 val accuracy: 0.401000
# lr 4.603673e-08 reg 2.610706e+06 train accuracy: 0.412041 val accuracy: 0.417000
# lr 4.609915e-08 reg 2.060851e+06 train accuracy: 0.409469 val accuracy: 0.417000
# lr 4.616138e-08 reg 1.282576e+06 train accuracy: 0.408939 val accuracy: 0.404000
# lr 4.719310e-08 reg 4.778030e+06 train accuracy: 0.406122 val accuracy: 0.401000
# lr 4.740268e-08 reg 2.127654e+06 train accuracy: 0.402367 val accuracy: 0.395000
# lr 4.760590e-08 reg 2.710631e+06 train accuracy: 0.398490 val accuracy: 0.391000
# lr 4.798352e-08 reg 1.631158e+06 train accuracy: 0.411898 val accuracy: 0.417000
# lr 4.811468e-08 reg 1.817288e+06 train accuracy: 0.408612 val accuracy: 0.420000
# lr 4.865276e-08 reg 6.571788e+04 train accuracy: 0.113673 val accuracy: 0.114000
# lr 4.892442e-08 reg 4.585702e+06 train accuracy: 0.376388 val accuracy: 0.383000
# lr 4.913140e-08 reg 2.704032e+06 train accuracy: 0.414694 val accuracy: 0.426000
# lr 4.913658e-08 reg 1.885070e+06 train accuracy: 0.407449 val accuracy: 0.409000
# lr 4.927710e-08 reg 1.026867e+06 train accuracy: 0.412449 val accuracy: 0.399000
# lr 4.941869e-08 reg 3.544285e+06 train accuracy: 0.398143 val accuracy: 0.397000
# lr 4.946091e-08 reg 1.034060e+06 train accuracy: 0.414694 val accuracy: 0.410000
# lr 4.956856e-08 reg 2.068934e+06 train accuracy: 0.410224 val accuracy: 0.413000
# lr 4.976756e-08 reg 3.029123e+06 train accuracy: 0.406939 val accuracy: 0.410000
# lr 5.000138e-08 reg 4.238938e+06 train accuracy: 0.412306 val accuracy: 0.393000
# lr 5.042598e-08 reg 4.344153e+06 train accuracy: 0.386388 val accuracy: 0.364000
# lr 5.043492e-08 reg 2.801387e+06 train accuracy: 0.404122 val accuracy: 0.403000
# lr 5.055304e-08 reg 4.037205e+06 train accuracy: 0.401204 val accuracy: 0.386000
# lr 5.068292e-08 reg 1.552056e+06 train accuracy: 0.404878 val accuracy: 0.405000
# lr 5.085939e-08 reg 1.735609e+06 train accuracy: 0.389857 val accuracy: 0.379000
# lr 5.178255e-08 reg 1.931957e+05 train accuracy: 0.121449 val accuracy: 0.119000
# lr 5.206186e-08 reg 2.795213e+06 train accuracy: 0.383612 val accuracy: 0.366000
# lr 5.224997e-08 reg 1.117132e+06 train accuracy: 0.413265 val accuracy: 0.420000
# lr 5.271442e-08 reg 6.648796e+05 train accuracy: 0.404959 val accuracy: 0.388000
# lr 5.308463e-08 reg 4.341139e+06 train accuracy: 0.396551 val accuracy: 0.401000
# lr 5.368701e-08 reg 2.066930e+06 train accuracy: 0.407653 val accuracy: 0.417000
# lr 5.387719e-08 reg 1.309333e+06 train accuracy: 0.404204 val accuracy: 0.393000
# lr 5.388056e-08 reg 1.623966e+06 train accuracy: 0.406592 val accuracy: 0.395000
# lr 5.400016e-08 reg 1.374338e+06 train accuracy: 0.395490 val accuracy: 0.383000
# lr 5.420661e-08 reg 1.353429e+06 train accuracy: 0.411347 val accuracy: 0.413000
# lr 5.516124e-08 reg 4.361349e+06 train accuracy: 0.390082 val accuracy: 0.406000
# lr 5.542594e-08 reg 2.408724e+06 train accuracy: 0.403490 val accuracy: 0.411000
# lr 5.550029e-08 reg 4.049854e+06 train accuracy: 0.393061 val accuracy: 0.391000
# lr 5.636491e-08 reg 4.966526e+06 train accuracy: 0.384878 val accuracy: 0.390000
# lr 5.639731e-08 reg 3.316961e+06 train accuracy: 0.396510 val accuracy: 0.385000
# lr 5.657272e-08 reg 3.360702e+06 train accuracy: 0.392776 val accuracy: 0.399000
# lr 5.671934e-08 reg 4.966254e+06 train accuracy: 0.384245 val accuracy: 0.391000
# lr 5.688830e-08 reg 1.928391e+06 train accuracy: 0.401653 val accuracy: 0.399000
# lr 5.741132e-08 reg 2.423075e+06 train accuracy: 0.398102 val accuracy: 0.392000
# lr 5.817858e-08 reg 2.647822e+06 train accuracy: 0.405918 val accuracy: 0.422000
# lr 5.838495e-08 reg 4.514256e+06 train accuracy: 0.387327 val accuracy: 0.393000
# lr 5.908950e-08 reg 2.090659e+06 train accuracy: 0.404347 val accuracy: 0.425000
# lr 5.916609e-08 reg 1.645379e+06 train accuracy: 0.407694 val accuracy: 0.420000
# lr 5.918823e-08 reg 5.642830e+04 train accuracy: 0.095796 val accuracy: 0.102000
# lr 5.950157e-08 reg 3.938395e+05 train accuracy: 0.339204 val accuracy: 0.347000
# lr 6.077465e-08 reg 1.039648e+06 train accuracy: 0.403000 val accuracy: 0.391000
# lr 6.139303e-08 reg 3.339030e+05 train accuracy: 0.261633 val accuracy: 0.259000
# lr 6.142936e-08 reg 4.444618e+06 train accuracy: 0.384959 val accuracy: 0.368000
# lr 6.220920e-08 reg 4.302104e+05 train accuracy: 0.388082 val accuracy: 0.389000
# lr 6.254195e-08 reg 2.216723e+06 train accuracy: 0.417796 val accuracy: 0.415000
# lr 6.284920e-08 reg 3.076982e+05 train accuracy: 0.196592 val accuracy: 0.185000
# lr 6.387160e-08 reg 9.987662e+05 train accuracy: 0.407694 val accuracy: 0.403000
# lr 6.426747e-08 reg 1.074749e+06 train accuracy: 0.405122 val accuracy: 0.408000
# lr 6.455234e-08 reg 8.562892e+05 train accuracy: 0.401306 val accuracy: 0.392000
# lr 6.500792e-08 reg 4.377925e+06 train accuracy: 0.383265 val accuracy: 0.406000
# lr 6.507099e-08 reg 3.043336e+06 train accuracy: 0.408918 val accuracy: 0.412000
# lr 6.521283e-08 reg 1.799550e+06 train accuracy: 0.401184 val accuracy: 0.369000
# lr 6.549613e-08 reg 1.171800e+06 train accuracy: 0.410449 val accuracy: 0.405000
# lr 6.571032e-08 reg 2.343463e+06 train accuracy: 0.396286 val accuracy: 0.377000
# lr 6.629995e-08 reg 1.226483e+06 train accuracy: 0.409571 val accuracy: 0.411000
# lr 6.649205e-08 reg 4.896027e+06 train accuracy: 0.369367 val accuracy: 0.393000
# lr 6.668248e-08 reg 1.265802e+06 train accuracy: 0.406959 val accuracy: 0.408000
# lr 6.739635e-08 reg 3.213428e+06 train accuracy: 0.393102 val accuracy: 0.387000
# lr 6.788132e-08 reg 2.156787e+06 train accuracy: 0.399306 val accuracy: 0.393000
# lr 6.794719e-08 reg 8.565958e+04 train accuracy: 0.100429 val accuracy: 0.102000
# lr 6.831004e-08 reg 1.594343e+06 train accuracy: 0.402633 val accuracy: 0.403000
# lr 6.851177e-08 reg 3.602770e+06 train accuracy: 0.400163 val accuracy: 0.395000
# lr 6.859346e-08 reg 3.841709e+06 train accuracy: 0.391408 val accuracy: 0.410000
# lr 6.867344e-08 reg 3.238689e+06 train accuracy: 0.396041 val accuracy: 0.397000
# lr 6.875106e-08 reg 4.071838e+06 train accuracy: 0.396531 val accuracy: 0.374000
# lr 6.878245e-08 reg 1.459555e+06 train accuracy: 0.394347 val accuracy: 0.389000
# lr 6.888191e-08 reg 4.305244e+06 train accuracy: 0.380633 val accuracy: 0.375000
# lr 6.888307e-08 reg 2.457870e+06 train accuracy: 0.405429 val accuracy: 0.410000
# lr 6.898565e-08 reg 3.418560e+05 train accuracy: 0.353204 val accuracy: 0.367000
# lr 6.907833e-08 reg 2.601132e+06 train accuracy: 0.397163 val accuracy: 0.396000
# lr 6.931838e-08 reg 2.156666e+06 train accuracy: 0.404020 val accuracy: 0.391000
# lr 6.961147e-08 reg 2.550278e+06 train accuracy: 0.400000 val accuracy: 0.430000
# lr 6.966887e-08 reg 1.457598e+05 train accuracy: 0.121224 val accuracy: 0.126000
# lr 6.979379e-08 reg 2.619804e+06 train accuracy: 0.378918 val accuracy: 0.353000
# lr 7.020056e-08 reg 1.359622e+06 train accuracy: 0.409245 val accuracy: 0.404000
# lr 7.126702e-08 reg 4.933458e+06 train accuracy: 0.388633 val accuracy: 0.397000
# lr 7.168674e-08 reg 1.408103e+06 train accuracy: 0.415245 val accuracy: 0.411000
# lr 7.254291e-08 reg 4.139566e+06 train accuracy: 0.390490 val accuracy: 0.398000
# lr 7.283894e-08 reg 3.707001e+06 train accuracy: 0.398837 val accuracy: 0.394000
# lr 7.309483e-08 reg 1.719343e+06 train accuracy: 0.394388 val accuracy: 0.384000
# lr 7.343809e-08 reg 1.492188e+06 train accuracy: 0.417796 val accuracy: 0.429000
# lr 7.377046e-08 reg 2.187487e+06 train accuracy: 0.398612 val accuracy: 0.375000
# lr 7.383545e-08 reg 4.505769e+05 train accuracy: 0.406837 val accuracy: 0.415000
# lr 7.394338e-08 reg 3.296253e+06 train accuracy: 0.384408 val accuracy: 0.379000
# lr 7.418297e-08 reg 3.800488e+06 train accuracy: 0.395490 val accuracy: 0.381000
# lr 7.478630e-08 reg 3.843753e+06 train accuracy: 0.379204 val accuracy: 0.390000
# lr 7.496070e-08 reg 8.242423e+05 train accuracy: 0.408367 val accuracy: 0.418000
# lr 7.563579e-08 reg 3.574635e+06 train accuracy: 0.383980 val accuracy: 0.402000
# lr 7.582689e-08 reg 3.483128e+06 train accuracy: 0.381510 val accuracy: 0.370000
# lr 7.613872e-08 reg 4.978342e+06 train accuracy: 0.380184 val accuracy: 0.376000
# lr 7.630203e-08 reg 4.076754e+06 train accuracy: 0.382694 val accuracy: 0.379000
# lr 7.640217e-08 reg 1.607408e+06 train accuracy: 0.405551 val accuracy: 0.411000
# lr 7.687775e-08 reg 3.518544e+05 train accuracy: 0.405184 val accuracy: 0.391000
# lr 7.690438e-08 reg 4.368058e+05 train accuracy: 0.414408 val accuracy: 0.409000
# lr 7.738709e-08 reg 1.468172e+06 train accuracy: 0.406061 val accuracy: 0.406000
# lr 7.808582e-08 reg 1.396561e+06 train accuracy: 0.407939 val accuracy: 0.420000
# lr 7.834500e-08 reg 3.957028e+06 train accuracy: 0.382245 val accuracy: 0.370000
# lr 8.031835e-08 reg 3.489251e+06 train accuracy: 0.387224 val accuracy: 0.389000
# lr 8.056936e-08 reg 1.070875e+06 train accuracy: 0.415755 val accuracy: 0.422000
# lr 8.070006e-08 reg 7.916421e+05 train accuracy: 0.408510 val accuracy: 0.406000
# lr 8.076224e-08 reg 1.775871e+06 train accuracy: 0.409918 val accuracy: 0.416000
# lr 8.090326e-08 reg 5.531442e+05 train accuracy: 0.412592 val accuracy: 0.418000
# lr 8.118088e-08 reg 2.976093e+06 train accuracy: 0.396122 val accuracy: 0.386000
# lr 8.196208e-08 reg 4.317871e+05 train accuracy: 0.411449 val accuracy: 0.404000
# lr 8.230785e-08 reg 2.106669e+06 train accuracy: 0.399939 val accuracy: 0.401000
# lr 8.309623e-08 reg 4.347678e+06 train accuracy: 0.373939 val accuracy: 0.378000
# lr 8.331752e-08 reg 2.276029e+06 train accuracy: 0.401776 val accuracy: 0.402000
# lr 8.334020e-08 reg 2.374171e+06 train accuracy: 0.412612 val accuracy: 0.411000
# lr 8.363724e-08 reg 1.499395e+06 train accuracy: 0.400653 val accuracy: 0.398000
# lr 8.398805e-08 reg 3.802393e+06 train accuracy: 0.383898 val accuracy: 0.386000
# lr 8.406200e-08 reg 9.334696e+05 train accuracy: 0.410408 val accuracy: 0.421000
# lr 8.410076e-08 reg 4.086329e+06 train accuracy: 0.385939 val accuracy: 0.393000
# lr 8.426697e-08 reg 2.943550e+06 train accuracy: 0.382857 val accuracy: 0.361000
# lr 8.431917e-08 reg 1.632190e+06 train accuracy: 0.388204 val accuracy: 0.379000
# lr 8.564946e-08 reg 8.894530e+05 train accuracy: 0.413592 val accuracy: 0.417000
# lr 8.615248e-08 reg 1.030377e+06 train accuracy: 0.410041 val accuracy: 0.398000
# lr 8.670866e-08 reg 4.329480e+06 train accuracy: 0.367184 val accuracy: 0.367000
# lr 8.683474e-08 reg 2.061591e+06 train accuracy: 0.418837 val accuracy: 0.418000
# lr 8.697330e-08 reg 2.306677e+06 train accuracy: 0.392224 val accuracy: 0.389000
# lr 8.753245e-08 reg 8.855342e+05 train accuracy: 0.413816 val accuracy: 0.419000
# lr 8.782414e-08 reg 3.332813e+06 train accuracy: 0.384306 val accuracy: 0.385000
# lr 8.786013e-08 reg 3.938263e+06 train accuracy: 0.393755 val accuracy: 0.398000
# lr 8.827535e-08 reg 2.455698e+06 train accuracy: 0.381796 val accuracy: 0.367000
# lr 8.835763e-08 reg 6.359606e+05 train accuracy: 0.402245 val accuracy: 0.399000
# lr 8.882277e-08 reg 8.728399e+05 train accuracy: 0.412469 val accuracy: 0.403000
# lr 8.921050e-08 reg 4.622164e+06 train accuracy: 0.359612 val accuracy: 0.346000
# lr 8.972796e-08 reg 1.419806e+06 train accuracy: 0.403673 val accuracy: 0.389000
# lr 8.983593e-08 reg 8.644795e+04 train accuracy: 0.112714 val accuracy: 0.105000
# lr 9.001129e-08 reg 2.591265e+06 train accuracy: 0.404694 val accuracy: 0.422000
# lr 9.061582e-08 reg 1.423628e+06 train accuracy: 0.401490 val accuracy: 0.395000
# lr 9.094649e-08 reg 3.696296e+05 train accuracy: 0.414041 val accuracy: 0.402000
# lr 9.132382e-08 reg 2.683324e+06 train accuracy: 0.365245 val accuracy: 0.352000
# lr 9.153554e-08 reg 2.058814e+06 train accuracy: 0.400694 val accuracy: 0.396000
# lr 9.172092e-08 reg 9.363763e+05 train accuracy: 0.410408 val accuracy: 0.420000
# lr 9.191837e-08 reg 7.764595e+05 train accuracy: 0.412694 val accuracy: 0.407000
# lr 9.301129e-08 reg 1.090390e+06 train accuracy: 0.396673 val accuracy: 0.387000
# lr 9.318954e-08 reg 4.707855e+05 train accuracy: 0.408143 val accuracy: 0.417000
# lr 9.345848e-08 reg 3.549832e+06 train accuracy: 0.373776 val accuracy: 0.393000
# lr 9.370978e-08 reg 4.997728e+06 train accuracy: 0.366571 val accuracy: 0.352000
# lr 9.489488e-08 reg 3.841783e+06 train accuracy: 0.380286 val accuracy: 0.357000
# lr 9.507445e-08 reg 4.446766e+06 train accuracy: 0.381694 val accuracy: 0.379000
# lr 9.585857e-08 reg 4.705208e+06 train accuracy: 0.363898 val accuracy: 0.354000
# lr 9.608023e-08 reg 3.194447e+06 train accuracy: 0.391163 val accuracy: 0.396000
# lr 9.609765e-08 reg 4.176874e+05 train accuracy: 0.410347 val accuracy: 0.408000
# lr 9.623521e-08 reg 5.055511e+04 train accuracy: 0.109918 val accuracy: 0.110000
# lr 9.716459e-08 reg 1.500347e+06 train accuracy: 0.401061 val accuracy: 0.392000
# lr 9.728870e-08 reg 4.144101e+06 train accuracy: 0.374592 val accuracy: 0.380000
# lr 9.745155e-08 reg 2.014937e+06 train accuracy: 0.398306 val accuracy: 0.399000
# lr 9.790512e-08 reg 1.965336e+06 train accuracy: 0.403837 val accuracy: 0.415000
# lr 9.793126e-08 reg 4.344752e+06 train accuracy: 0.389347 val accuracy: 0.418000
# lr 9.796321e-08 reg 2.751535e+06 train accuracy: 0.391429 val accuracy: 0.377000
# lr 9.798453e-08 reg 4.176227e+06 train accuracy: 0.371531 val accuracy: 0.378000
# lr 9.803399e-08 reg 2.287838e+06 train accuracy: 0.389204 val accuracy: 0.396000
# lr 9.806455e-08 reg 1.035126e+06 train accuracy: 0.414633 val accuracy: 0.414000
# lr 9.810951e-08 reg 1.414841e+06 train accuracy: 0.399837 val accuracy: 0.389000
# lr 9.817214e-08 reg 7.793203e+05 train accuracy: 0.417245 val accuracy: 0.409000
# lr 9.827226e-08 reg 3.796526e+06 train accuracy: 0.377653 val accuracy: 0.404000
# lr 9.835479e-08 reg 9.206926e+05 train accuracy: 0.410224 val accuracy: 0.396000
# lr 9.848626e-08 reg 3.815992e+06 train accuracy: 0.388776 val accuracy: 0.360000
# lr 9.881970e-08 reg 3.683056e+06 train accuracy: 0.378082 val accuracy: 0.382000
# best validation accuracy achieved during cross-validation: 0.430000

# %%
# A useful debugging strategy is to plot the loss as a function of
# iteration number:
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.402

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=True)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

results = {}
hidden_size = 500
input_size = X_train_feats.shape[1]
num_classes = 10

re_run = 1
max_iteration = 10000

range_learning_rate = np.array([1e-1, 9.5e-1])
range_reg = np.array([5e-9, 1e-5])
range_decay = np.array([0.9, 1])

for i in range(re_run):

  # # initial search for hyperparameter
  # learning_rate = 10 ** np.random.uniform(-8, 1)

    reg_value = 10 ** np.random.uniform(-9, -5)

    learning_rate = np.random.uniform(range_learning_rate[0],
            range_learning_rate[1])

  # reg_value = np.random.uniform(range_reg[0], range_reg[1])

    decay = np.random.uniform(range_decay[0], range_decay[1])

    learning_rate = 8.780883e-01
    reg_value = 2.269228e-06
    decay = 9.231259e-01

    net = TwoLayerNet(input_size, hidden_size, num_classes)
    stats = net.train(
        X_train_feats,
        y_train,
        X_val_feats,
        y_val,
        num_iters=max_iteration,
        batch_size=200,
        learning_rate=learning_rate,
        learning_rate_decay=decay,
        reg=reg_value,
        verbose=False,
        )

    accuracy_train = (net.predict(X_train_feats) == y_train).mean()
    val_acc = (net.predict(X_val_feats) == y_val).mean()

    results[learning_rate, reg_value, decay] = [accuracy_train, val_acc]

    if val_acc > best_accuracy:
        best_accuracy = val_acc
        best_net = net

  # Print out results.

for (lr, reg, decay) in sorted(results):
    (train_accuracy, val_accuracy) = results[(lr, reg, decay)]
    print('lr %e reg %e decay %e train accuracy: %f val accuracy: %f' \
        % (lr, reg, decay, train_accuracy, val_accuracy))

print('best validation accuracy achieved during cross-validation: %f' \
    % best_accuracy)

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# lr 8.780883e-01 reg 2.269228e-06 decay 9.231259e-01 train accuracy: 0.985102 val accuracy: 0.578000
# best validation accuracy achieved during cross-validation: 0.578000

# %%
print(val_acc)
# print(results)

for lr, reg, decay in sorted(results):
  train_accuracy, val_accuracy = results[(lr, reg, decay)]
  print('lr %e reg %e decay %e train accuracy: %f val accuracy: %f' % (
                lr, reg, decay, train_accuracy, val_accuracy))
# Out:
# 0.578
# lr 8.780883e-01 reg 2.269228e-06 decay 9.231259e-01 train accuracy: 0.985102 val accuracy: 0.578000

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.565

# %% [markdown]
# ---
# # IMPORTANT
#
# This is the end of this question. Please do the following:
#
# 1. Click `File -> Save` to make sure the latest checkpoint of this notebook is saved to your Drive.
# 2. Execute the cell below to download the modified `.py` files back to your drive.

# %%
import os

FOLDER_TO_SAVE = os.path.join('drive/My Drive/', FOLDERNAME)
FILES_TO_SAVE = []

for files in FILES_TO_SAVE:
  with open(os.path.join(FOLDER_TO_SAVE, '/'.join(files.split('/')[1:])), 'w') as f:
    f.write(''.join(open(files).readlines()))
